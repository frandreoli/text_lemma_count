# %% [markdown]
# # Text analysis: word split, count and lemmatization

# %% [markdown]
# ## Text functions

# %%
#Need: re, simplemma, pandas
import importlib

if "txt_mod" in globals():
    importlib.reload(txt_mod)
else:
    import text_local_module as txt_mod

# %% [markdown]
# ## PDF functions

# %% [markdown]
# ## Use cases

# %% [markdown]
# ### 1) Analyzing a text string

# %%
input_text = "Io mi  andare andai  molto     prova  chiamo.Mamma ciao bello bello \n,. /tanto bello mi ciao!!! So happy,vado all'ippodromo!,ddd \n\n\n\nmi"            
input_language = "it"
verbose_option = (True,False)[0]
text_object = txt_mod.text_analyzer(input_text, input_language, verbose_option)


print("A dictionary with all counted words is given by:\n", text_object.word_count())
txt_mod.word_count_print("andai", text_object)
txt_mod.word_count_print("test", text_object)

display(text_object.lemmatize())
display(text_object.lemma_count())
# Out:
# Please wait. I am processing the text.
# Please wait. I am splitting the words.
# Please wait. I am counting the words.
# A dictionary with all counted words is given by:
#  {'andai': 1, 'happy': 1, 'all': 1, 'molto': 1, 'ddd': 1, 'chiamo': 1, 'mamma': 1, 'so': 1, 'mi': 3, 'bello': 3, 'ippodromo': 1, 'io': 1, 'prova': 1, 'vado': 1, 'ciao': 2, 'andare': 1, 'tanto': 1}
# The word 'andai' occurs:  1 times
# The word 'test' occurs:  0 times
# Please wait. I am lemmatizing the text.
#           Raw      Lemma  Raw Count
# 0       andai     andare          1
# 1       happy      happy          1
# 2          al         al          1
# 3       molto      molto          1
# 4         ddd        ddd          1
# 5      chiamo   chiamare          1
# 6       mamma      mamma          1
# 7          so     sapere          1
# 8          mi         mi          3
# 9       bello      bello          3
# 10  ippodromo  ippodromo          1
# 11         io         io          1
# 12      prova      prova          1
# 13       vado     andare          1
# 14       ciao       ciao          2
# 15     andare     andare          1
# 16      tanto    tangere          1
# Please wait. I am counting the lemmas.
#         Lemma  Lemma Count             Occurrence
# 0          al            1                   [al]
# 1      andare            3  [andai, vado, andare]
# 2       bello            3                [bello]
# 3    chiamare            1               [chiamo]
# 4        ciao            2                 [ciao]
# 5         ddd            1                  [ddd]
# 6       happy            1                [happy]
# 7          io            1                   [io]
# 8   ippodromo            1            [ippodromo]
# 9       mamma            1                [mamma]
# 10         mi            3                   [mi]
# 11      molto            1                [molto]
# 12      prova            1                [prova]
# 13     sapere            1                   [so]
# 14    tangere            1                [tanto]
